# %%
import pandas as pd

# %%
data = pd.read_csv('./inst/extdata/ctr_nils_bm_human.csv')
newdata =pd.DataFrame()
newdata['source'] = data['Ligand.Cluster']
newdata['target'] = data['Receptor.Cluster']
newdata['gene_A'] = data['Ligand']
newdata['gene_B'] = data['Receptor']
newdata['type_gene_A'] = 'Ligand'
newdata['type_gene_B']= 'Receptor'
newdata['MeanLR']=data['MeanLR']
newdata.to_csv('./inst/extdata/ctr_nils_bm_human_newformat.csv')

# %%
data = pd.read_csv('./inst/extdata/exp_nils_bm_human.csv')
newdata =pd.DataFrame()
newdata['source'] = data['Ligand.Cluster']
newdata['target'] = data['Receptor.Cluster']
newdata['gene_A'] = data['Ligand']
newdata['gene_B'] = data['Receptor']
newdata['type_gene_A'] = 'Ligand'
newdata['type_gene_B']= 'Receptor'
newdata['MeanLR']=data['MeanLR']
newdata.to_csv('./inst/extdata/exp_nils_bm_human_newformat.csv')

# %%
# Out:
#           source         target gene_A gene_B type_gene_A type_gene_B
# 0         Neural     Fibroblast  CALM2   MYLK      Ligand    Receptor
# 1        Myeloid        Myeloid   JAM3   JAM3      Ligand    Receptor
# 2            MSC     Fibroblast  PSEN1   CD44      Ligand    Receptor
# 3     Fibroblast     Fibroblast   HAS2   CD44      Ligand    Receptor
# 4         Neural            MSC  CALM1   INSR      Ligand    Receptor
# ...          ...            ...    ...    ...         ...         ...
# 4379     Myeloid         Neural   RHAG  ICAM4      Ligand    Receptor
# 4380     Myeloid            MSC   RHAG  ICAM4      Ligand    Receptor
# 4381     Myeloid     Fibroblast   RHAG  ICAM4      Ligand    Receptor
# 4382     Myeloid  Megakaryocyte   RHAG  ICAM4      Ligand    Receptor
# 4383     Myeloid        Myeloid   RHAG  ICAM4      Ligand    Receptor
#
# [4384 rows x 6 columns]
